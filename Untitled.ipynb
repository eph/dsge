# %%
from dsge.examples import sw

# %%
import numpy as np
swlin = sw.compile_model()

# %%
# %timeit swlin.log_lik(sw.p0(), filter='kalman_filter',t0=4)
# Out:
# 19.1 ms ± 1.86 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
swlin.log_lik(sw.p0(),t0=4,filter='kalman_filter')
# Out:
# -805.7045655625577

# %%
# %timeit res = swlin.kf_everything(sw.p0())
# Out:
# 72.7 ms ± 852 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
u,s,v = np.random.rand(3,3)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('dark_background')
#res['smoothed_means'].a.plot()
res['filtered_stds'].a.plot()
res['smoothed_stds'].a.plot()

# %%
from tabula import read_pdf

columns = [22.1,153.2,183,208,235,265,292,320,350,348,380,409,433,460,487,516,551]
names=['Forecaster','Real GDP','GDP Prices','Nominal GDP','CPI']
read_pdf("/home/eherbst/Downloads/test_blue_chip.pdf",area=[25,670,595,208],verbose=True,guess=False)#,pandas_options=dict(skiprows=5))
# Out:
#                                     S  MARCH 10, 2009  \
# 0   Forecast Tumbles 0.7 Of A Percentage Point To ...
# 1   ercent Change 2009 From 2008 (Year-Over-Year) ...
# 2                                               3 4 5
# 3                 Nominal Consumer Indust. Dis. Pers.
# 4                              GDP Price Prod. Income
# 5                     (Cur. $) Index (Total) (2000 $)
# 6                               -0.4 1.0 H -1.9 H 1.0
# 7                                -0.2 H -0.3 -6.4 1.9
# 8                                  -0.6 -1.2 -7.6 1.6
# 9                                  -0.6 -0.6 -8.6 2.4
# 10                                 -1.1 -1.9 -5.7 2.8
# 11                                 -1.0 -0.2 -7.4 1.4
# 12                                 -1.2 -0.6 -5.0 1.0
# 13                                 -0.5 -0.2 -8.8 1.1
# 14                                -0.9 -0.6 -10.4 1.2
# 15                                 -1.0 -1.2 -5.4 1.3
# ...
